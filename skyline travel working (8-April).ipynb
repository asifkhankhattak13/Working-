# %%
import pandas as pd

# %%
data = pd.read_csv("skyline travel.csv", encoding ='latin1', index_col = 0 )

# %%
data.head()
# Out:
#          id  Gender Satisfied  Age  Age Band   Type of Travel     Class  \
# Ref
# 0     70172    Male         Y   13  Under 18  Personal Travel  Eco Plus
# 1      5047    Male         N   25  25 to 34  Business travel  Business
# 2    110028  Female         Y   26  25 to 34  Business travel  Business
# 3     24026  Female         Y   25  25 to 34  Business travel  Business
# 4    119299    Male         Y   61  55 to 64  Business travel  Business
#
#      Flight Distance          Destination Continent  ...  Seat comfort  \
# Ref                                                  ...
# 0               4760                India      Asia  ...             5
# 1                235  Republic of Ireland    Europe  ...             1
# 2               4760                India      Asia  ...             5
# 3                560               Norway    Europe  ...             2
# 4               4760                India      Asia  ...             5
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 27 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Ref                                103904 non-null  int64
#  1   id                                 103904 non-null  int64
#  2   Gender                             103904 non-null  object
#  3   Satisfied                          103904 non-null  object
#  4   Age                                103904 non-null  int64
#  5   Age Band                           103904 non-null  object
#  6   Type of Travel                     103904 non-null  object
#  7   Class                              103904 non-null  object
#  8   Flight Distance                    103904 non-null  int64
#  9   Destination                        103904 non-null  object
#  10  Continent                          103904 non-null  object
# ...

# %%
data.columns
# Out:
# Index(['Ref', 'id', 'Gender', 'Satisfied', 'Age', 'Age Band', 'Type of Travel',
#        'Class', 'Flight Distance', 'Destination', 'Continent',
#        'Inflight wifi service', 'Departure/Arrival time convenient',
#        'Ease of Online booking', 'Gate location', 'Food and drink',
#        'Online boarding', 'Seat comfort', 'Inflight entertainment',
#        'On-board service', 'Leg room service', 'Baggage handling',
#        'Checkin service', 'Inflight service', 'Cleanliness',
#        'Departure Delay in Minutes', 'Arrival Delay in Minutes'],
#       dtype='object')

# %%
data.describe()
# Out:
#                  Ref             id            Age  Flight Distance  \
# count  103904.000000  103904.000000  103904.000000    103904.000000
# mean    51951.500000   64924.210502      39.379706      4164.071066
# std     29994.645522   37463.812252      15.114964      1346.755749
# min         0.000000       1.000000       7.000000       235.000000
# 25%     25975.750000   32533.750000      27.000000      4760.000000
# 50%     51951.500000   64856.500000      40.000000      4760.000000
# 75%     77927.250000   97368.250000      51.000000      4760.000000
# max    103903.000000  129880.000000      85.000000      5940.000000
#
#        Inflight wifi service  Departure/Arrival time convenient  \
# count          103904.000000                      103904.000000
# mean                2.522319                           3.060248
# std                 1.447848                           1.525143
# min                 0.000000                           0.000000
# ...

# %%
data.isnull().sum()
# Out:
# Ref                                    0
# id                                     0
# Gender                                 0
# Satisfied                              0
# Age                                    0
# Age Band                               0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Destination                            0
# Continent                              0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# ...

# %%
data.dtypes
# Out:
# Ref                                    int64
# id                                     int64
# Gender                                object
# Satisfied                             object
# Age                                    int64
# Age Band                              object
# Type of Travel                        object
# Class                                 object
# Flight Distance                        int64
# Destination                           object
# Continent                             object
# Inflight wifi service                  int64
# Departure/Arrival time convenient      int64
# Ease of Online booking                 int64
# Gate location                          int64
# Food and drink                         int64
# Online boarding                        int64
# Seat comfort                           int64
# Inflight entertainment                 int64
# On-board service                       int64
# Leg room service                       int64
# ...

# %%
data.head()
# Out:
#    Ref      id  Gender Satisfied  Age  Age Band   Type of Travel     Class  \
# 0    0   70172    Male         Y   13  Under 18  Personal Travel  Eco Plus
# 1    1    5047    Male         N   25  25 to 34  Business travel  Business
# 2    2  110028  Female         Y   26  25 to 34  Business travel  Business
# 3    3   24026  Female         Y   25  25 to 34  Business travel  Business
# 4    4  119299    Male         Y   61  55 to 64  Business travel  Business
#
#    Flight Distance          Destination  ... Seat comfort  \
# 0             4760                India  ...            5
# 1              235  Republic of Ireland  ...            1
# 2             4760                India  ...            5
# 3              560               Norway  ...            2
# 4             4760                India  ...            5
#
#    Inflight entertainment  On-board service  Leg room service  \
# 0                       5                 4                 3
# ...

# %%
data['Gender'].value_counts()
# Out:
# Gender
# Female    52727
# Male      51177
# Name: count, dtype: int64

# %%
data['Satisfied'].value_counts()
# Out:
# Satisfied
# Y    84920
# N    18984
# Name: count, dtype: int64

# %%
data['Class'].value_counts()
# Out:
# Class
# Business    49665
# Eco         46745
# Eco Plus     7494
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.countplot(x='Satisfied', hue='Gender', data=data)
plt.title('Satisfaction by Gender')
plt.show()

# %%
sns.countplot(x='Class', hue='Satisfied', data=data)
plt.title('Satisfaction by Travel Class')
plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(12,8))
sns.heatmap(data.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title('Correlation between numerical features')
plt.show()
